# %% [markdown]
# In \[2\]:
#
#     import pandas as pd
#     import numpy as np
#
# In \[3\]:
#
#     df=pd.read_csv("weather.csv")
#
# In \[4\]:
#
#     df
#
# Out\[4\]:
#
# |     | MinTemp | MaxTemp | Rainfall | Evaporation | Sunshine | WindGustDir | WindGustSpeed | WindDir9am | WindDir3pm | WindSpeed9am | ... | Humidity3pm | Pressure9am | Pressure3pm | Cloud9am | Cloud3pm | Temp9am | Temp3pm | RainToday | RISK_MM | RainTomorrow |
# |-----|---------|---------|----------|-------------|----------|-------------|---------------|------------|------------|--------------|-----|-------------|-------------|-------------|----------|----------|---------|---------|-----------|---------|--------------|
# | 0   | 8.0     | 24.3    | 0.0      | 3.4         | 6.3      | NW          | 30.0          | SW         | NW         | 6.0          | ... | 29          | 1019.7      | 1015.0      | 7        | 7        | 14.4    | 23.6    | No        | 3.6     | Yes          |
# | 1   | 14.0    | 26.9    | 3.6      | 4.4         | 9.7      | ENE         | 39.0          | E          | W          | 4.0          | ... | 36          | 1012.4      | 1008.4      | 5        | 3        | 17.5    | 25.7    | Yes       | 3.6     | Yes          |
# | 2   | 13.7    | 23.4    | 3.6      | 5.8         | 3.3      | NW          | 85.0          | N          | NNE        | 6.0          | ... | 69          | 1009.5      | 1007.2      | 8        | 7        | 15.4    | 20.2    | Yes       | 39.8    | Yes          |
# | 3   | 13.3    | 15.5    | 39.8     | 7.2         | 9.1      | NW          | 54.0          | WNW        | W          | 30.0         | ... | 56          | 1005.5      | 1007.0      | 2        | 7        | 13.5    | 14.1    | Yes       | 2.8     | Yes          |
# | 4   | 7.6     | 16.1    | 2.8      | 5.6         | 10.6     | SSE         | 50.0          | SSE        | ESE        | 20.0         | ... | 49          | 1018.3      | 1018.5      | 7        | 7        | 11.1    | 15.4    | Yes       | 0.0     | No           |
# | ... | ...     | ...     | ...      | ...         | ...      | ...         | ...           | ...        | ...        | ...          | ... | ...         | ...         | ...         | ...      | ...      | ...     | ...     | ...       | ...     | ...          |
# | 361 | 9.0     | 30.7    | 0.0      | 7.6         | 12.1     | NNW         | 76.0          | SSE        | NW         | 7.0          | ... | 15          | 1016.1      | 1010.8      | 1        | 3        | 20.4    | 30.0    | No        | 0.0     | No           |
# | 362 | 7.1     | 28.4    | 0.0      | 11.6        | 12.7     | N           | 48.0          | NNW        | NNW        | 2.0          | ... | 22          | 1020.0      | 1016.9      | 0        | 1        | 17.2    | 28.2    | No        | 0.0     | No           |
# | 363 | 12.5    | 19.9    | 0.0      | 8.4         | 5.3      | ESE         | 43.0          | ENE        | ENE        | 11.0         | ... | 47          | 1024.0      | 1022.8      | 3        | 2        | 14.5    | 18.3    | No        | 0.0     | No           |
# | 364 | 12.5    | 26.9    | 0.0      | 5.0         | 7.1      | NW          | 46.0          | SSW        | WNW        | 6.0          | ... | 39          | 1021.0      | 1016.2      | 6        | 7        | 15.8    | 25.9    | No        | 0.0     | No           |
# | 365 | 12.3    | 30.2    | 0.0      | 6.0         | 12.6     | NW          | 78.0          | NW         | WNW        | 31.0         | ... | 13          | 1009.6      | 1009.2      | 1        | 1        | 23.8    | 28.6    | No        | 0.0     | No           |
#
# 366 rows × 22 columns
#
# In \[5\]:
#
#     df.head()
#
# Out\[5\]:
#
# |     | MinTemp | MaxTemp | Rainfall | Evaporation | Sunshine | WindGustDir | WindGustSpeed | WindDir9am | WindDir3pm | WindSpeed9am | ... | Humidity3pm | Pressure9am | Pressure3pm | Cloud9am | Cloud3pm | Temp9am | Temp3pm | RainToday | RISK_MM | RainTomorrow |
# |-----|---------|---------|----------|-------------|----------|-------------|---------------|------------|------------|--------------|-----|-------------|-------------|-------------|----------|----------|---------|---------|-----------|---------|--------------|
# | 0   | 8.0     | 24.3    | 0.0      | 3.4         | 6.3      | NW          | 30.0          | SW         | NW         | 6.0          | ... | 29          | 1019.7      | 1015.0      | 7        | 7        | 14.4    | 23.6    | No        | 3.6     | Yes          |
# | 1   | 14.0    | 26.9    | 3.6      | 4.4         | 9.7      | ENE         | 39.0          | E          | W          | 4.0          | ... | 36          | 1012.4      | 1008.4      | 5        | 3        | 17.5    | 25.7    | Yes       | 3.6     | Yes          |
# | 2   | 13.7    | 23.4    | 3.6      | 5.8         | 3.3      | NW          | 85.0          | N          | NNE        | 6.0          | ... | 69          | 1009.5      | 1007.2      | 8        | 7        | 15.4    | 20.2    | Yes       | 39.8    | Yes          |
# | 3   | 13.3    | 15.5    | 39.8     | 7.2         | 9.1      | NW          | 54.0          | WNW        | W          | 30.0         | ... | 56          | 1005.5      | 1007.0      | 2        | 7        | 13.5    | 14.1    | Yes       | 2.8     | Yes          |
# | 4   | 7.6     | 16.1    | 2.8      | 5.6         | 10.6     | SSE         | 50.0          | SSE        | ESE        | 20.0         | ... | 49          | 1018.3      | 1018.5      | 7        | 7        | 11.1    | 15.4    | Yes       | 0.0     | No           |
#
# 5 rows × 22 columns
#
# In \[6\]:
#
#     df.tail()
#
# Out\[6\]:
#
# |     | MinTemp | MaxTemp | Rainfall | Evaporation | Sunshine | WindGustDir | WindGustSpeed | WindDir9am | WindDir3pm | WindSpeed9am | ... | Humidity3pm | Pressure9am | Pressure3pm | Cloud9am | Cloud3pm | Temp9am | Temp3pm | RainToday | RISK_MM | RainTomorrow |
# |-----|---------|---------|----------|-------------|----------|-------------|---------------|------------|------------|--------------|-----|-------------|-------------|-------------|----------|----------|---------|---------|-----------|---------|--------------|
# | 361 | 9.0     | 30.7    | 0.0      | 7.6         | 12.1     | NNW         | 76.0          | SSE        | NW         | 7.0          | ... | 15          | 1016.1      | 1010.8      | 1        | 3        | 20.4    | 30.0    | No        | 0.0     | No           |
# | 362 | 7.1     | 28.4    | 0.0      | 11.6        | 12.7     | N           | 48.0          | NNW        | NNW        | 2.0          | ... | 22          | 1020.0      | 1016.9      | 0        | 1        | 17.2    | 28.2    | No        | 0.0     | No           |
# | 363 | 12.5    | 19.9    | 0.0      | 8.4         | 5.3      | ESE         | 43.0          | ENE        | ENE        | 11.0         | ... | 47          | 1024.0      | 1022.8      | 3        | 2        | 14.5    | 18.3    | No        | 0.0     | No           |
# | 364 | 12.5    | 26.9    | 0.0      | 5.0         | 7.1      | NW          | 46.0          | SSW        | WNW        | 6.0          | ... | 39          | 1021.0      | 1016.2      | 6        | 7        | 15.8    | 25.9    | No        | 0.0     | No           |
# | 365 | 12.3    | 30.2    | 0.0      | 6.0         | 12.6     | NW          | 78.0          | NW         | WNW        | 31.0         | ... | 13          | 1009.6      | 1009.2      | 1        | 1        | 23.8    | 28.6    | No        | 0.0     | No           |
#
# 5 rows × 22 columns
#
# In \[9\]:
#
#     df.info
#
# Out\[9\]:
#
#     <bound method DataFrame.info of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
#     0        8.0     24.3       0.0          3.4       6.3          NW
#     1       14.0     26.9       3.6          4.4       9.7         ENE
#     2       13.7     23.4       3.6          5.8       3.3          NW
#     3       13.3     15.5      39.8          7.2       9.1          NW
#     4        7.6     16.1       2.8          5.6      10.6         SSE
#     ..       ...      ...       ...          ...       ...         ...
#     361      9.0     30.7       0.0          7.6      12.1         NNW
#     362      7.1     28.4       0.0         11.6      12.7           N
#     363     12.5     19.9       0.0          8.4       5.3         ESE
#     364     12.5     26.9       0.0          5.0       7.1          NW
#     365     12.3     30.2       0.0          6.0      12.6          NW
#
#          WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
#     0             30.0         SW         NW           6.0  ...           29
#     1             39.0          E          W           4.0  ...           36
#     2             85.0          N        NNE           6.0  ...           69
#     3             54.0        WNW          W          30.0  ...           56
#     4             50.0        SSE        ESE          20.0  ...           49
#     ..             ...        ...        ...           ...  ...          ...
#     361           76.0        SSE         NW           7.0  ...           15
#     362           48.0        NNW        NNW           2.0  ...           22
#     363           43.0        ENE        ENE          11.0  ...           47
#     364           46.0        SSW        WNW           6.0  ...           39
#     365           78.0         NW        WNW          31.0  ...           13
#
#          Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
#     0         1019.7       1015.0         7         7     14.4     23.6
#     1         1012.4       1008.4         5         3     17.5     25.7
#     2         1009.5       1007.2         8         7     15.4     20.2
#     3         1005.5       1007.0         2         7     13.5     14.1
#     4         1018.3       1018.5         7         7     11.1     15.4
#     ..           ...          ...       ...       ...      ...      ...
#     361       1016.1       1010.8         1         3     20.4     30.0
#     362       1020.0       1016.9         0         1     17.2     28.2
#     363       1024.0       1022.8         3         2     14.5     18.3
#     364       1021.0       1016.2         6         7     15.8     25.9
#     365       1009.6       1009.2         1         1     23.8     28.6
#
#          RainToday  RISK_MM RainTomorrow
#     0           No      3.6          Yes
#     1          Yes      3.6          Yes
#     2          Yes     39.8          Yes
#     3          Yes      2.8          Yes
#     4          Yes      0.0           No
#     ..         ...      ...          ...
#     361         No      0.0           No
#     362         No      0.0           No
#     363         No      0.0           No
#     364         No      0.0           No
#     365         No      0.0           No
#
#     [366 rows x 22 columns]>
#
# In \[8\]:
#
#     df.describe
#
# Out\[8\]:
#
#     <bound method NDFrame.describe of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
#     0        8.0     24.3       0.0          3.4       6.3          NW
#     1       14.0     26.9       3.6          4.4       9.7         ENE
#     2       13.7     23.4       3.6          5.8       3.3          NW
#     3       13.3     15.5      39.8          7.2       9.1          NW
#     4        7.6     16.1       2.8          5.6      10.6         SSE
#     ..       ...      ...       ...          ...       ...         ...
#     361      9.0     30.7       0.0          7.6      12.1         NNW
#     362      7.1     28.4       0.0         11.6      12.7           N
#     363     12.5     19.9       0.0          8.4       5.3         ESE
#     364     12.5     26.9       0.0          5.0       7.1          NW
#     365     12.3     30.2       0.0          6.0      12.6          NW
#
#          WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
#     0             30.0         SW         NW           6.0  ...           29
#     1             39.0          E          W           4.0  ...           36
#     2             85.0          N        NNE           6.0  ...           69
#     3             54.0        WNW          W          30.0  ...           56
#     4             50.0        SSE        ESE          20.0  ...           49
#     ..             ...        ...        ...           ...  ...          ...
#     361           76.0        SSE         NW           7.0  ...           15
#     362           48.0        NNW        NNW           2.0  ...           22
#     363           43.0        ENE        ENE          11.0  ...           47
#     364           46.0        SSW        WNW           6.0  ...           39
#     365           78.0         NW        WNW          31.0  ...           13
#
#          Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
#     0         1019.7       1015.0         7         7     14.4     23.6
#     1         1012.4       1008.4         5         3     17.5     25.7
#     2         1009.5       1007.2         8         7     15.4     20.2
#     3         1005.5       1007.0         2         7     13.5     14.1
#     4         1018.3       1018.5         7         7     11.1     15.4
#     ..           ...          ...       ...       ...      ...      ...
#     361       1016.1       1010.8         1         3     20.4     30.0
#     362       1020.0       1016.9         0         1     17.2     28.2
#     363       1024.0       1022.8         3         2     14.5     18.3
#     364       1021.0       1016.2         6         7     15.8     25.9
#     365       1009.6       1009.2         1         1     23.8     28.6
#
#          RainToday  RISK_MM RainTomorrow
#     0           No      3.6          Yes
#     1          Yes      3.6          Yes
#     2          Yes     39.8          Yes
#     3          Yes      2.8          Yes
#     4          Yes      0.0           No
#     ..         ...      ...          ...
#     361         No      0.0           No
#     362         No      0.0           No
#     363         No      0.0           No
#     364         No      0.0           No
#     365         No      0.0           No
#
#     [366 rows x 22 columns]>
#
# In \[7\]:
#
#     df.columns
#
# Out\[7\]:
#
#     Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#            'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#            'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#            'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#            'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#           dtype='object')
#
# In \[11\]:
#
#     df.shape
#
# Out\[11\]:
#
#     (366, 22)
#
# In \[12\]:
#
#     df.size
#
# Out\[12\]:
#
#     8052
#
# In \[13\]:
#
#     df.index
#
# Out\[13\]:
#
#     RangeIndex(start=0, stop=366, step=1)
#
# In \[14\]:
#
#     df.dtypes
#
# Out\[14\]:
#
#     MinTemp          float64
#     MaxTemp          float64
#     Rainfall         float64
#     Evaporation      float64
#     Sunshine         float64
#     WindGustDir       object
#     WindGustSpeed    float64
#     WindDir9am        object
#     WindDir3pm        object
#     WindSpeed9am     float64
#     WindSpeed3pm       int64
#     Humidity9am        int64
#     Humidity3pm        int64
#     Pressure9am      float64
#     Pressure3pm      float64
#     Cloud9am           int64
#     Cloud3pm           int64
#     Temp9am          float64
#     Temp3pm          float64
#     RainToday         object
#     RISK_MM          float64
#     RainTomorrow      object
#     dtype: object
#
# In \[17\]:
#
#     df['Sunshine'].unique()
#
# Out\[17\]:
#
#     array([ 6.3,  9.7,  3.3,  9.1, 10.6,  8.2,  8.4,  4.6,  4.1,  7.7, 11.9,
#            12.5, 13. , 12.4, 13.1, 11.1, 10.1, 10.4,  9.5,  0. ,  0.6,  7.5,
#             8.1,  8.9,  2.3, 10.7,  0.4,  0.5,  0.2, 12. ,  4.7, 11.8,  9.8,
#             8.8, 10. ,  7.3,  3.6, 12.7,  0.9,  8.7,  0.8,  5.9, 10.2, 12.1,
#             5.6,  7.1, 13.2, 13.6, 12.8, 10.5,  2.2, 11.7, 12.6, 13.3,  6.9,
#            13.5,  6. , 11.6,  0.1,  1.6, 10.8,  9.9,  9. ,  6.2,  9.2,  0.3,
#             8. ,  9.6,  3.8,  8.6, 11. , 11.3, 11.5, 11.2,  8.5, 11.4,  1.9,
#            10.3,  9.3,  7.8,  6.8,  6.1,  8.3,  4.9,  7.9,  6.5,  5.8,  7. ,
#             9.4,  3. ,  4.3,  1.7,  6.7,  5.1,  2.7,  2.6,  nan,  7.2,  2. ,
#             7.6,  6.4,  3.9,  2.8,  1.2,  5.2,  0.7,  4.2,  5. ,  1.8,  2.4,
#             2.9, 10.9, 12.2,  3.5,  5.3])
#
# In \[18\]:
#
#     df['Evaporation'].unique()
#
# Out\[18\]:
#
#     array([ 3.4,  4.4,  5.8,  7.2,  5.6,  4.2,  4. ,  5.4,  6.2,  8.8,  8.4,
#             7.4,  8. ,  9.2,  2.8,  1.2,  6.8,  6.6,  7. ,  2.6,  2.4,  1.6,
#             3.8,  6. , 10.4,  4.8,  5. ,  6.4,  1.8,  7.8,  8.2,  5.2,  9.6,
#            11.4,  7.6, 12.6,  9. , 10. ,  9.4, 13.8, 12.4,  1.4, 10.2,  3.2,
#             8.6,  4.6,  3.6,  2.2,  3. ,  2. ,  1. ,  0.6,  0.2,  0.8, 11.6])
#
# In \[19\]:
#
#     df['Humidity3pm'].value_counts
#
# Out\[19\]:
#
#     <bound method IndexOpsMixin.value_counts of 0      29
#     1      36
#     2      69
#     3      56
#     4      49
#            ..
#     361    15
#     362    22
#     363    47
#     364    39
#     365    13
#     Name: Humidity3pm, Length: 366, dtype: int64>
#
# In \[21\]:
#
#     df['Humidity3pm'].count
#
# Out\[21\]:
#
#     <bound method Series.count of 0      29
#     1      36
#     2      69
#     3      56
#     4      49
#            ..
#     361    15
#     362    22
#     363    47
#     364    39
#     365    13
#     Name: Humidity3pm, Length: 366, dtype: int64>
#
# In \[22\]:
#
#     import pandas as pd
#
#     # Load the CSV file into a DataFrame
#     weather_data = pd.read_csv("weather.csv")
#
#     # Extract unique MaxTemp values
#     unique_max_temp_values = weather_data['MaxTemp'].unique()
#
#     # Print the unique MaxTemp values
#     print("Unique MaxTemp values:")
#     print(unique_max_temp_values)
#
#     Unique MaxTemp values:
#     [24.3 26.9 23.4 15.5 16.1 16.9 18.2 17.  19.5 22.8 25.2 27.3 27.9 30.9
#      31.2 32.1 30.  32.3 33.4 19.4 18.5 28.4 22.2 28.  24.1 20.4 26.3 24.2
#      26.5 21.8 26.8 25.8 28.2 29.4 24.8 21.5 20.3 27.1 29.9 21.1 21.7 20.9
#      21.  23.1 29.5 22.  24.4 26.7 28.3 31.6 35.  33.5 34.2 25.3 27.5 34.1
#      33.9 30.3 35.8 35.7 33.8 33.2 25.1 19.6 24.7 19.9 22.5 27.8 25.7 28.8
#      31.3 34.9 23.8 29.6 22.6 27.4 26.  26.1 28.9 28.6 25.9 27.6 17.3 18.4
#      31.8 29.2 31.7 34.7 33.1 35.2 30.2 26.2 29.3 14.8 24.9 22.4 17.4 20.2
#      18.3 18.9 18.8 23.3 14.3 21.4 20.5 22.9 19.8 18.  20.7 19.3 19.7 18.7
#      20.6 19.  21.2 11.3 13.8 17.1 16.7 16.8 17.6 18.1 19.2 18.6 17.9 16.
#      12.3 14.1 14.7 14.5 17.5 14.  15.7 14.4 15.1 16.3 13.7 15.  16.4 13.
#      11.8 15.9 11.7 13.9 12.9 12.6 15.4 13.1 11.5 12.  14.2 11.1  9.5  8.8
#       8.7  8.4 11.  16.5 13.6 12.8 10.6 11.6 11.2 12.2  9.7 10.7 10.9 12.5
#       9.6  7.6  9.3 10.4 16.2 17.2 12.1 12.4 15.2 16.6 21.6 25.5 13.2 21.9
#      21.3 20.  23.9 28.5 30.7]
#
# In \[23\]:
#
#     import pandas as pd
#
#     # Load the CSV file into a DataFrame
#     weather_data = pd.read_csv("weather.csv")
#
#     # Filter the DataFrame where Rainfall is exactly 0
#     clear_days = weather_data[weather_data['Rainfall'] == 0]
#
#     # Count the number of clear days
#     num_clear_days = clear_days.shape[0]
#
#     # Print the number of clear days
#     print("Number of days with no rainfall:", num_clear_days)
#
#     Number of days with no rainfall: 263
#
# In \[24\]:
#
#     import pandas as pd
#
#     # Load the CSV file into a DataFrame
#     weather_data = pd.read_csv("weather.csv")
#
#     # Filter the DataFrame where WindGustDir is exactly 'NW'
#     nw_occurrences = weather_data[weather_data['WindGustDir'] == 'NW']
#
#     # Count the number of occurrences
#     num_nw_occurrences = nw_occurrences.shape[0]
#
#     # Print the number of occurrences
#     print("Number of times WindGustDir was NW:", num_nw_occurrences)
#
#     Number of times WindGustDir was NW: 73
#
# In \[25\]:
#
#     # Check for null values in the DataFrame
#     null_values = weather_data.isnull().sum()
#
#     # Print the null values
#     print("Null values in the weather dataset:")
#     print(null_values)
#
#     Null values in the weather dataset:
#     MinTemp           0
#     MaxTemp           0
#     Rainfall          0
#     Evaporation       0
#     Sunshine          3
#     WindGustDir       3
#     WindGustSpeed     2
#     WindDir9am       31
#     WindDir3pm        1
#     WindSpeed9am      7
#     WindSpeed3pm      0
#     Humidity9am       0
#     Humidity3pm       0
#     Pressure9am       0
#     Pressure3pm       0
#     Cloud9am          0
#     Cloud3pm          0
#     Temp9am           0
#     Temp3pm           0
#     RainToday         0
#     RISK_MM           0
#     RainTomorrow      0
#     dtype: int64
#
# In \[28\]:
#
#     import pandas as pd
#
#     # Load the CSV file into a DataFrame
#     weather_data = pd.read_csv("weather.csv")
#
#     # Check the column names
#     print(weather_data.columns)
#
#     # Filtering: Let's say we want to filter out rows where the 'Rainfall' column is greater than 1.0
#     filtered_data = weather_data[weather_data['Rainfall'] > 1.0]
#
#     # Grouping: Let's say we want to group the data by 'Location' and find the average 'MaxTemp' for each location
#     grouped_data = weather_data.groupby('Sunshine')['MaxTemp'].mean()
#
#     # Print the filtered data
#     print("Filtered Data where Rainfall > 1.0:")
#     print(filtered_data)
#
#     # Print the grouped data
#     print("\nGrouped Data by Location with Average MaxTemp:")
#     print(grouped_data)
#
#     Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#            'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#            'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#            'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#            'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#           dtype='object')
#     Filtered Data where Rainfall > 1.0:
#          MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
#     1       14.0     26.9       3.6          4.4       9.7         ENE
#     2       13.7     23.4       3.6          5.8       3.3          NW
#     3       13.3     15.5      39.8          7.2       9.1          NW
#     4        7.6     16.1       2.8          5.6      10.6         SSE
#     9        8.4     22.8      16.2          5.4       7.7           E
#     ..       ...      ...       ...          ...       ...         ...
#     327      7.8     16.2      17.4          6.4       7.9          NW
#     338     14.4     20.7       7.6          9.4       4.9         NNW
#     339     10.3     21.3       3.0          4.2       6.7         NNW
#     341      0.3     16.0       8.2          5.4      11.8          NW
#     348     11.9     21.1      13.2          6.6       NaN          NW
#
#          WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
#     1             39.0          E          W           4.0  ...           36
#     2             85.0          N        NNE           6.0  ...           69
#     3             54.0        WNW          W          30.0  ...           56
#     4             50.0        SSE        ESE          20.0  ...           49
#     9             31.0          S        ESE           7.0  ...           32
#     ..             ...        ...        ...           ...  ...          ...
#     327           50.0         NW          N          15.0  ...           44
#     338           33.0        NNW        NNW          20.0  ...           65
#     339           43.0        ENE          N           7.0  ...           46
#     341           57.0        NNW          N          11.0  ...           45
#     348           41.0        NNE          N           7.0  ...           61
#
#          Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
#     1         1012.4       1008.4         5         3     17.5     25.7
#     2         1009.5       1007.2         8         7     15.4     20.2
#     3         1005.5       1007.0         2         7     13.5     14.1
#     4         1018.3       1018.5         7         7     11.1     15.4
#     9         1024.1       1020.7         7         1     13.3     21.7
#     ..           ...          ...       ...       ...      ...      ...
#     327       1016.7       1017.8         7         1      8.0     14.3
#     338       1015.5       1013.2         8         4     14.5     19.3
#     339       1018.1       1013.6         8         1     11.7     19.8
#     341       1016.8       1013.3         1         1      6.9     14.6
#     348       1019.2       1016.7         7         3     14.5     19.4
#
#          RainToday  RISK_MM RainTomorrow
#     1          Yes      3.6          Yes
#     2          Yes     39.8          Yes
#     3          Yes      2.8          Yes
#     4          Yes      0.0           No
#     9          Yes      0.0           No
#     ..         ...      ...          ...
#     327        Yes      0.0           No
#     338        Yes      3.0          Yes
#     339        Yes      0.0           No
#     341        Yes      0.0           No
#     348        Yes      0.6           No
#
#     [66 rows x 22 columns]
#
#     Grouped Data by Location with Average MaxTemp:
#     Sunshine
#     0.0     15.70
#     0.1     20.40
#     0.2     15.75
#     0.3     22.80
#     0.4     21.25
#             ...
#     13.1    31.20
#     13.2    30.75
#     13.3    35.80
#     13.5    33.80
#     13.6    32.55
#     Name: MaxTemp, Length: 114, dtype: float64
#
# In \[35\]:
#
#     import pandas as pd
#
#     # Load the dataset
#     df = pd.read_csv('weather.csv')
#
#     # Check for missing values using isnull()
#     print("Missing values:")
#     print(df.isnull())
#
#     # Check for non-missing values using notnull()
#     print("\nNon-missing values:")
#     print(df.notnull())
#
#     Missing values:
#          MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
#     0      False    False     False        False     False        False
#     1      False    False     False        False     False        False
#     2      False    False     False        False     False        False
#     3      False    False     False        False     False        False
#     4      False    False     False        False     False        False
#     ..       ...      ...       ...          ...       ...          ...
#     361    False    False     False        False     False        False
#     362    False    False     False        False     False        False
#     363    False    False     False        False     False        False
#     364    False    False     False        False     False        False
#     365    False    False     False        False     False        False
#
#          WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
#     0            False       False       False         False  ...        False
#     1            False       False       False         False  ...        False
#     2            False       False       False         False  ...        False
#     3            False       False       False         False  ...        False
#     4            False       False       False         False  ...        False
#     ..             ...         ...         ...           ...  ...          ...
#     361          False       False       False         False  ...        False
#     362          False       False       False         False  ...        False
#     363          False       False       False         False  ...        False
#     364          False       False       False         False  ...        False
#     365          False       False       False         False  ...        False
#
#          Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
#     0          False        False     False     False    False    False
#     1          False        False     False     False    False    False
#     2          False        False     False     False    False    False
#     3          False        False     False     False    False    False
#     4          False        False     False     False    False    False
#     ..           ...          ...       ...       ...      ...      ...
#     361        False        False     False     False    False    False
#     362        False        False     False     False    False    False
#     363        False        False     False     False    False    False
#     364        False        False     False     False    False    False
#     365        False        False     False     False    False    False
#
#          RainToday  RISK_MM  RainTomorrow
#     0        False    False         False
#     1        False    False         False
#     2        False    False         False
#     3        False    False         False
#     4        False    False         False
#     ..         ...      ...           ...
#     361      False    False         False
#     362      False    False         False
#     363      False    False         False
#     364      False    False         False
#     365      False    False         False
#
#     [366 rows x 22 columns]
#
#     Non-missing values:
#          MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
#     0       True     True      True         True      True         True
#     1       True     True      True         True      True         True
#     2       True     True      True         True      True         True
#     3       True     True      True         True      True         True
#     4       True     True      True         True      True         True
#     ..       ...      ...       ...          ...       ...          ...
#     361     True     True      True         True      True         True
#     362     True     True      True         True      True         True
#     363     True     True      True         True      True         True
#     364     True     True      True         True      True         True
#     365     True     True      True         True      True         True
#
#          WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
#     0             True        True        True          True  ...         True
#     1             True        True        True          True  ...         True
#     2             True        True        True          True  ...         True
#     3             True        True        True          True  ...         True
#     4             True        True        True          True  ...         True
#     ..             ...         ...         ...           ...  ...          ...
#     361           True        True        True          True  ...         True
#     362           True        True        True          True  ...         True
#     363           True        True        True          True  ...         True
#     364           True        True        True          True  ...         True
#     365           True        True        True          True  ...         True
#
#          Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
#     0           True         True      True      True     True     True
#     1           True         True      True      True     True     True
#     2           True         True      True      True     True     True
#     3           True         True      True      True     True     True
#     4           True         True      True      True     True     True
#     ..           ...          ...       ...       ...      ...      ...
#     361         True         True      True      True     True     True
#     362         True         True      True      True     True     True
#     363         True         True      True      True     True     True
#     364         True         True      True      True     True     True
#     365         True         True      True      True     True     True
#
#          RainToday  RISK_MM  RainTomorrow
#     0         True     True          True
#     1         True     True          True
#     2         True     True          True
#     3         True     True          True
#     4         True     True          True
#     ..         ...      ...           ...
#     361       True     True          True
#     362       True     True          True
#     363       True     True          True
#     364       True     True          True
#     365       True     True          True
#
#     [366 rows x 22 columns]
#
# In \[36\]:
#
#     import pandas as pd
#
#     # Load the dataset
#     df = pd.read_csv('weather.csv')
#
#     # Display the original column names
#     print("Original column names:")
#     print(df.columns)
#
#     # Rename columns
#     new_column_names = {
#         'WindDir3pm': 'WD',
#         'Rainfall': 'RF',
#         'MinTemp': 'MT'
#     }
#
#     df.rename(columns=new_column_names, inplace=True)
#
#     # Display the updated column names
#     print("\nUpdated column names:")
#     print(df.columns)
#
#     Original column names:
#     Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#            'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#            'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#            'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#            'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#           dtype='object')
#
#     Updated column names:
#     Index(['MT', 'MaxTemp', 'RF', 'Evaporation', 'Sunshine', 'WindGustDir',
#            'WindGustSpeed', 'WindDir9am', 'WD', 'WindSpeed9am', 'WindSpeed3pm',
#            'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am',
#            'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'RISK_MM',
#            'RainTomorrow'],
#           dtype='object')
#
# In \[38\]:
#
#     df
#
# Out\[38\]:
#
# |     | MT   | MaxTemp | RF   | Evaporation | Sunshine | WindGustDir | WindGustSpeed | WindDir9am | WD  | WindSpeed9am | ... | Humidity3pm | Pressure9am | Pressure3pm | Cloud9am | Cloud3pm | Temp9am | Temp3pm | RainToday | RISK_MM | RainTomorrow |
# |-----|------|---------|------|-------------|----------|-------------|---------------|------------|-----|--------------|-----|-------------|-------------|-------------|----------|----------|---------|---------|-----------|---------|--------------|
# | 0   | 8.0  | 24.3    | 0.0  | 3.4         | 6.3      | NW          | 30.0          | SW         | NW  | 6.0          | ... | 29          | 1019.7      | 1015.0      | 7        | 7        | 14.4    | 23.6    | No        | 3.6     | Yes          |
# | 1   | 14.0 | 26.9    | 3.6  | 4.4         | 9.7      | ENE         | 39.0          | E          | W   | 4.0          | ... | 36          | 1012.4      | 1008.4      | 5        | 3        | 17.5    | 25.7    | Yes       | 3.6     | Yes          |
# | 2   | 13.7 | 23.4    | 3.6  | 5.8         | 3.3      | NW          | 85.0          | N          | NNE | 6.0          | ... | 69          | 1009.5      | 1007.2      | 8        | 7        | 15.4    | 20.2    | Yes       | 39.8    | Yes          |
# | 3   | 13.3 | 15.5    | 39.8 | 7.2         | 9.1      | NW          | 54.0          | WNW        | W   | 30.0         | ... | 56          | 1005.5      | 1007.0      | 2        | 7        | 13.5    | 14.1    | Yes       | 2.8     | Yes          |
# | 4   | 7.6  | 16.1    | 2.8  | 5.6         | 10.6     | SSE         | 50.0          | SSE        | ESE | 20.0         | ... | 49          | 1018.3      | 1018.5      | 7        | 7        | 11.1    | 15.4    | Yes       | 0.0     | No           |
# | ... | ...  | ...     | ...  | ...         | ...      | ...         | ...           | ...        | ... | ...          | ... | ...         | ...         | ...         | ...      | ...      | ...     | ...     | ...       | ...     | ...          |
# | 361 | 9.0  | 30.7    | 0.0  | 7.6         | 12.1     | NNW         | 76.0          | SSE        | NW  | 7.0          | ... | 15          | 1016.1      | 1010.8      | 1        | 3        | 20.4    | 30.0    | No        | 0.0     | No           |
# | 362 | 7.1  | 28.4    | 0.0  | 11.6        | 12.7     | N           | 48.0          | NNW        | NNW | 2.0          | ... | 22          | 1020.0      | 1016.9      | 0        | 1        | 17.2    | 28.2    | No        | 0.0     | No           |
# | 363 | 12.5 | 19.9    | 0.0  | 8.4         | 5.3      | ESE         | 43.0          | ENE        | ENE | 11.0         | ... | 47          | 1024.0      | 1022.8      | 3        | 2        | 14.5    | 18.3    | No        | 0.0     | No           |
# | 364 | 12.5 | 26.9    | 0.0  | 5.0         | 7.1      | NW          | 46.0          | SSW        | WNW | 6.0          | ... | 39          | 1021.0      | 1016.2      | 6        | 7        | 15.8    | 25.9    | No        | 0.0     | No           |
# | 365 | 12.3 | 30.2    | 0.0  | 6.0         | 12.6     | NW          | 78.0          | NW         | WNW | 31.0         | ... | 13          | 1009.6      | 1009.2      | 1        | 1        | 23.8    | 28.6    | No        | 0.0     | No           |
#
# 366 rows × 22 columns
#
# In \[40\]:
#
#     import pandas as pd
#
#     # Load the dataset
#     df = pd.read_csv('weather.csv')
#
#     # Exclude non-numeric columns
#     numeric_columns = df.select_dtypes(include=['int64', 'float64'])
#
#     # Calculate mean
#     mean_values = numeric_columns.mean()
#     print("Mean values:")
#     print(mean_values)
#
#     # Calculate standard deviation
#     std_values = numeric_columns.std()
#     print("\nStandard deviation values:")
#     print(std_values)
#
#     # Calculate variance
#     var_values = numeric_columns.var()
#     print("\nVariance values:")
#     print(var_values)
#
#     Mean values:
#     MinTemp             7.265574
#     MaxTemp            20.550273
#     Rainfall            1.428415
#     Evaporation         4.521858
#     Sunshine            7.909366
#     WindGustSpeed      39.840659
#     WindSpeed9am        9.651811
#     WindSpeed3pm       17.986339
#     Humidity9am        72.035519
#     Humidity3pm        44.519126
#     Pressure9am      1019.709016
#     Pressure3pm      1016.810383
#     Cloud9am            3.890710
#     Cloud3pm            4.024590
#     Temp9am            12.358470
#     Temp3pm            19.230874
#     RISK_MM             1.428415
#     dtype: float64
#
#     Standard deviation values:
#     MinTemp           6.025800
#     MaxTemp           6.690516
#     Rainfall          4.225800
#     Evaporation       2.669383
#     Sunshine          3.481517
#     WindGustSpeed    13.059807
#     WindSpeed9am      7.951929
#     WindSpeed3pm      8.856997
#     Humidity9am      13.137058
#     Humidity3pm      16.850947
#     Pressure9am       6.686212
#     Pressure3pm       6.469422
#     Cloud9am          2.956131
#     Cloud3pm          2.666268
#     Temp9am           5.630832
#     Temp3pm           6.640346
#     RISK_MM           4.225800
#     dtype: float64
#
#     Variance values:
#     MinTemp           36.310264
#     MaxTemp           44.763000
#     Rainfall          17.857382
#     Evaporation        7.125603
#     Sunshine          12.120962
#     WindGustSpeed    170.558563
#     WindSpeed9am      63.233174
#     WindSpeed3pm      78.446388
#     Humidity9am      172.582297
#     Humidity3pm      283.954428
#     Pressure9am       44.705425
#     Pressure3pm       41.853426
#     Cloud9am           8.738708
#     Cloud3pm           7.108983
#     Temp9am           31.706271
#     Temp3pm           44.094195
#     RISK_MM           17.857382
#     dtype: float64
#
# In \[41\]:
#
#     import pandas as pd
#
#     # Load the CSV file into a DataFrame
#     weather_data = pd.read_csv('weather.csv')
#
#     # Assuming 'Rainfall' is the column containing rainfall data
#     rainfall_column = 'Rainfall'
#
#     # Calculate the mean rainfall
#     mean_rainfall = weather_data[rainfall_column].mean()
#
#     print("Mean Rainfall:", mean_rainfall)
#
#     Mean Rainfall: 1.428415300546448
#
# In \[42\]:
#
#     import pandas as pd
#
#     # Load the CSV file into a DataFrame
#     weather_data = pd.read_csv('weather.csv')
#
#     # Assuming 'Cloud3pm' is the column containing Cloud3pm data
#     cloud_3pm_column = 'Cloud3pm'
#
#     # Calculate the standard deviation of Cloud3pm
#     std_dev_cloud_3pm = weather_data[cloud_3pm_column].std()
#
#     print("Standard Deviation of Cloud3pm:", std_dev_cloud_3pm)
#
#     Standard Deviation of Cloud3pm: 2.666267561271102
#
# In \[44\]:
#
#     import pandas as pd
#
#     # Load the CSV file into a DataFrame
#     weather_data = pd.read_csv("weather.csv")
#
#     # Assuming your CSV file has a column named 'Evaporation'
#     evaporation_data = weather_data[weather_data['Evaporation'].notnull()]
#
#     # Print the instances where evaporation is recorded
#     print(evaporation_data)
#
#          MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
#     0        8.0     24.3       0.0          3.4       6.3          NW
#     1       14.0     26.9       3.6          4.4       9.7         ENE
#     2       13.7     23.4       3.6          5.8       3.3          NW
#     3       13.3     15.5      39.8          7.2       9.1          NW
#     4        7.6     16.1       2.8          5.6      10.6         SSE
#     ..       ...      ...       ...          ...       ...         ...
#     361      9.0     30.7       0.0          7.6      12.1         NNW
#     362      7.1     28.4       0.0         11.6      12.7           N
#     363     12.5     19.9       0.0          8.4       5.3         ESE
#     364     12.5     26.9       0.0          5.0       7.1          NW
#     365     12.3     30.2       0.0          6.0      12.6          NW
#
#          WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
#     0             30.0         SW         NW           6.0  ...           29
#     1             39.0          E          W           4.0  ...           36
#     2             85.0          N        NNE           6.0  ...           69
#     3             54.0        WNW          W          30.0  ...           56
#     4             50.0        SSE        ESE          20.0  ...           49
#     ..             ...        ...        ...           ...  ...          ...
#     361           76.0        SSE         NW           7.0  ...           15
#     362           48.0        NNW        NNW           2.0  ...           22
#     363           43.0        ENE        ENE          11.0  ...           47
#     364           46.0        SSW        WNW           6.0  ...           39
#     365           78.0         NW        WNW          31.0  ...           13
#
#          Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
#     0         1019.7       1015.0         7         7     14.4     23.6
#     1         1012.4       1008.4         5         3     17.5     25.7
#     2         1009.5       1007.2         8         7     15.4     20.2
#     3         1005.5       1007.0         2         7     13.5     14.1
#     4         1018.3       1018.5         7         7     11.1     15.4
#     ..           ...          ...       ...       ...      ...      ...
#     361       1016.1       1010.8         1         3     20.4     30.0
#     362       1020.0       1016.9         0         1     17.2     28.2
#     363       1024.0       1022.8         3         2     14.5     18.3
#     364       1021.0       1016.2         6         7     15.8     25.9
#     365       1009.6       1009.2         1         1     23.8     28.6
#
#          RainToday  RISK_MM RainTomorrow
#     0           No      3.6          Yes
#     1          Yes      3.6          Yes
#     2          Yes     39.8          Yes
#     3          Yes      2.8          Yes
#     4          Yes      0.0           No
#     ..         ...      ...          ...
#     361         No      0.0           No
#     362         No      0.0           No
#     363         No      0.0           No
#     364         No      0.0           No
#     365         No      0.0           No
#
#     [366 rows x 22 columns]
#
# In \[47\]:
#
#     import pandas as pd
#
#     # Load the dataset
#     df = pd.read_csv('weather.csv')
#
#     # Iterate over unique values of 'RainToday'
#     for rain_today_value in df['RainToday'].unique():
#         print(f"RainToday: {rain_today_value}")
#         for column in df.columns:
#             if column != 'RainToday':
#                 # Check if the column contains numeric data
#                 if pd.api.types.is_numeric_dtype(df[column]):
#                     min_value = df[df['RainToday'] == rain_today_value][column].min()
#                     max_value = df[df['RainToday'] == rain_today_value][column].max()
#                     print(f"Column: {column}, Min: {min_value}, Max: {max_value}")
#                 else:
#                     print(f"Column {column} contains non-numeric data, skipping...")
#         print("\n")
#
#     RainToday: No
#     Column: MinTemp, Min: -5.3, Max: 20.9
#     Column: MaxTemp, Min: 7.6, Max: 35.8
#     Column: Rainfall, Min: 0.0, Max: 1.0
#     Column: Evaporation, Min: 0.6, Max: 13.8
#     Column: Sunshine, Min: 0.0, Max: 13.6
#     Column WindGustDir contains non-numeric data, skipping...
#     Column: WindGustSpeed, Min: 13.0, Max: 83.0
#     Column WindDir9am contains non-numeric data, skipping...
#     Column WindDir3pm contains non-numeric data, skipping...
#     Column: WindSpeed9am, Min: 0.0, Max: 35.0
#     Column: WindSpeed3pm, Min: 2, Max: 50
#     Column: Humidity9am, Min: 36, Max: 99
#     Column: Humidity3pm, Min: 13, Max: 96
#     Column: Pressure9am, Min: 999.4, Max: 1035.7
#     Column: Pressure3pm, Min: 997.5, Max: 1033.2
#     Column: Cloud9am, Min: 0, Max: 8
#     Column: Cloud3pm, Min: 0, Max: 8
#     Column: Temp9am, Min: 0.1, Max: 24.7
#     Column: Temp3pm, Min: 5.1, Max: 34.5
#     Column: RISK_MM, Min: 0.0, Max: 25.8
#     Column RainTomorrow contains non-numeric data, skipping...
#
#
#     RainToday: Yes
#     Column: MinTemp, Min: -1.6, Max: 19.9
#     Column: MaxTemp, Min: 8.4, Max: 33.8
#     Column: Rainfall, Min: 1.2, Max: 39.8
#     Column: Evaporation, Min: 0.2, Max: 10.2
#     Column: Sunshine, Min: 0.0, Max: 13.5
#     Column WindGustDir contains non-numeric data, skipping...
#     Column: WindGustSpeed, Min: 22.0, Max: 98.0
#     Column WindDir9am contains non-numeric data, skipping...
#     Column WindDir3pm contains non-numeric data, skipping...
#     Column: WindSpeed9am, Min: 0.0, Max: 41.0
#     Column: WindSpeed3pm, Min: 0, Max: 52
#     Column: Humidity9am, Min: 53, Max: 99
#     Column: Humidity3pm, Min: 26, Max: 94
#     Column: Pressure9am, Min: 996.5, Max: 1028.2
#     Column: Pressure3pm, Min: 996.8, Max: 1025.7
#     Column: Cloud9am, Min: 1, Max: 8
#     Column: Cloud3pm, Min: 1, Max: 8
#     Column: Temp9am, Min: 5.5, Max: 23.0
#     Column: Temp3pm, Min: 7.1, Max: 31.8
#     Column: RISK_MM, Min: 0.0, Max: 39.8
#     Column RainTomorrow contains non-numeric data, skipping...
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
